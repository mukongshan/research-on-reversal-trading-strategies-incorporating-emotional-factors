# %%
import os
import pandas as pd

# ===== 配置 =====
SCORED_FILE = "../../../mid_result/hs300_data/merged_all_scored_titles.csv"   # 680W 大文件，含 标题 + 基础分数
ROOT_DIR = "../../../mid_result/hs300_data/stocks_words_data"  # 子目录的根目录
OUTPUT_NAME = "titles_with_score.csv"  # 输出文件名（避免覆盖原始）

# ===== 1. 读大文件，生成映射 =====
print("加载大文件中...")
big_df = pd.read_csv(SCORED_FILE, usecols=["标题", "基础分数"])
score_map = dict(zip(big_df["标题"], big_df["基础分数"]))
print(f"大文件加载完成，共 {len(score_map)} 条映射")
# Out:
# 加载大文件中...
# 大文件加载完成，共 5946885 条映射

# %%
# ===== 2. 遍历子目录，处理小文件 =====
for code in os.listdir(ROOT_DIR):
    subdir = os.path.join(ROOT_DIR, code)
    if not os.path.isdir(subdir):
        continue

    file_path = os.path.join(subdir, "titles_time_fixed.csv")
    if not os.path.exists(file_path):
        continue

    print(f"处理股票 {code} ...")
    try:
        df = pd.read_csv(file_path)
        if "标题" not in df.columns:
            print(f"⚠️ 文件 {file_path} 缺少 '标题' 列，跳过")
            continue

        # 查基础分数
        df["基础分数"] = df["标题"].map(score_map)

        # 输出（存在每个子目录下）
        out_path = os.path.join(subdir, OUTPUT_NAME)
        df.to_csv(out_path, index=False, encoding="utf-8-sig")
        print(f"✅ 已输出 {out_path}")

    except Exception as e:
        print(f"❌ 处理 {file_path} 出错: {e}")

print("全部处理完成！")
# Out:
# 处理股票 000001 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000001\titles_with_score.csv
# 处理股票 000002 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000002\titles_with_score.csv
# 处理股票 000063 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000063\titles_with_score.csv
# 处理股票 000100 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000100\titles_with_score.csv
# 处理股票 000157 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000157\titles_with_score.csv
# 处理股票 000166 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000166\titles_with_score.csv
# 处理股票 000301 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000301\titles_with_score.csv
# 处理股票 000333 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000333\titles_with_score.csv
# 处理股票 000338 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000338\titles_with_score.csv
# 处理股票 000408 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000408\titles_with_score.csv
# 处理股票 000425 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000425\titles_with_score.csv
# 处理股票 000538 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000538\titles_with_score.csv
# 处理股票 000568 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000568\titles_with_score.csv
# 处理股票 000596 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000596\titles_with_score.csv
# 处理股票 000617 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000617\titles_with_score.csv
# 处理股票 000625 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000625\titles_with_score.csv
# 处理股票 000630 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000630\titles_with_score.csv
# 处理股票 000651 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000651\titles_with_score.csv
# 处理股票 000661 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000661\titles_with_score.csv
# 处理股票 000708 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000708\titles_with_score.csv
# 处理股票 000725 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000725\titles_with_score.csv
# 处理股票 000768 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000768\titles_with_score.csv
# 处理股票 000776 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000776\titles_with_score.csv
# 处理股票 000786 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000786\titles_with_score.csv
# 处理股票 000792 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000792\titles_with_score.csv
# 处理股票 000800 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000800\titles_with_score.csv
# 处理股票 000807 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000807\titles_with_score.csv
# 处理股票 000858 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000858\titles_with_score.csv
# 处理股票 000876 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000876\titles_with_score.csv
# 处理股票 000895 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000895\titles_with_score.csv
# 处理股票 000938 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000938\titles_with_score.csv
# 处理股票 000963 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000963\titles_with_score.csv
# 处理股票 000975 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000975\titles_with_score.csv
# 处理股票 000977 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000977\titles_with_score.csv
# 处理股票 000983 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000983\titles_with_score.csv
# 处理股票 000999 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\000999\titles_with_score.csv
# 处理股票 001289 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\001289\titles_with_score.csv
# 处理股票 001965 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\001965\titles_with_score.csv
# 处理股票 001979 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\001979\titles_with_score.csv
# 处理股票 002001 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002001\titles_with_score.csv
# 处理股票 002007 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002007\titles_with_score.csv
# 处理股票 002027 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002027\titles_with_score.csv
# 处理股票 002028 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002028\titles_with_score.csv
# 处理股票 002049 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002049\titles_with_score.csv
# 处理股票 002050 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002050\titles_with_score.csv
# 处理股票 002074 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002074\titles_with_score.csv
# 处理股票 002129 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002129\titles_with_score.csv
# 处理股票 002142 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002142\titles_with_score.csv
# 处理股票 002179 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002179\titles_with_score.csv
# 处理股票 002180 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002180\titles_with_score.csv
# 处理股票 002230 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002230\titles_with_score.csv
# 处理股票 002236 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002236\titles_with_score.csv
# 处理股票 002241 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002241\titles_with_score.csv
# 处理股票 002252 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002252\titles_with_score.csv
# 处理股票 002271 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002271\titles_with_score.csv
# 处理股票 002304 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002304\titles_with_score.csv
# 处理股票 002311 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002311\titles_with_score.csv
# 处理股票 002352 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002352\titles_with_score.csv
# 处理股票 002371 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002371\titles_with_score.csv
# 处理股票 002415 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002415\titles_with_score.csv
# 处理股票 002422 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002422\titles_with_score.csv
# 处理股票 002459 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002459\titles_with_score.csv
# 处理股票 002460 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002460\titles_with_score.csv
# 处理股票 002463 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002463\titles_with_score.csv
# 处理股票 002466 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002466\titles_with_score.csv
# 处理股票 002475 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002475\titles_with_score.csv
# 处理股票 002493 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002493\titles_with_score.csv
# 处理股票 002555 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002555\titles_with_score.csv
# 处理股票 002594 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002594\titles_with_score.csv
# 处理股票 002601 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002601\titles_with_score.csv
# 处理股票 002648 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002648\titles_with_score.csv
# 处理股票 002709 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002709\titles_with_score.csv
# 处理股票 002714 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002714\titles_with_score.csv
# 处理股票 002736 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002736\titles_with_score.csv
# 处理股票 002812 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002812\titles_with_score.csv
# 处理股票 002916 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002916\titles_with_score.csv
# 处理股票 002920 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002920\titles_with_score.csv
# 处理股票 002938 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\002938\titles_with_score.csv
# 处理股票 003816 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\003816\titles_with_score.csv
# 处理股票 300014 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300014\titles_with_score.csv
# 处理股票 300015 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300015\titles_with_score.csv
# 处理股票 300033 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300033\titles_with_score.csv
# 处理股票 300059 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300059\titles_with_score.csv
# 处理股票 300122 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300122\titles_with_score.csv
# 处理股票 300124 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300124\titles_with_score.csv
# 处理股票 300274 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300274\titles_with_score.csv
# 处理股票 300308 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300308\titles_with_score.csv
# 处理股票 300316 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300316\titles_with_score.csv
# 处理股票 300347 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300347\titles_with_score.csv
# 处理股票 300394 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300394\titles_with_score.csv
# 处理股票 300408 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300408\titles_with_score.csv
# 处理股票 300413 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300413\titles_with_score.csv
# 处理股票 300418 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300418\titles_with_score.csv
# 处理股票 300433 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300433\titles_with_score.csv
# 处理股票 300442 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300442\titles_with_score.csv
# 处理股票 300450 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300450\titles_with_score.csv
# 处理股票 300498 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300498\titles_with_score.csv
# 处理股票 300502 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300502\titles_with_score.csv
# 处理股票 300628 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300628\titles_with_score.csv
# 处理股票 300661 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300661\titles_with_score.csv
# 处理股票 300750 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300750\titles_with_score.csv
# 处理股票 300759 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300759\titles_with_score.csv
# 处理股票 300760 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300760\titles_with_score.csv
# 处理股票 300782 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300782\titles_with_score.csv
# 处理股票 300832 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300832\titles_with_score.csv
# 处理股票 300896 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300896\titles_with_score.csv
# 处理股票 300979 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300979\titles_with_score.csv
# 处理股票 300999 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\300999\titles_with_score.csv
# 处理股票 301269 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\301269\titles_with_score.csv
# 处理股票 600000 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600000\titles_with_score.csv
# 处理股票 600009 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600009\titles_with_score.csv
# 处理股票 600010 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600010\titles_with_score.csv
# 处理股票 600011 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600011\titles_with_score.csv
# 处理股票 600015 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600015\titles_with_score.csv
# 处理股票 600016 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600016\titles_with_score.csv
# 处理股票 600018 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600018\titles_with_score.csv
# 处理股票 600019 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600019\titles_with_score.csv
# 处理股票 600023 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600023\titles_with_score.csv
# 处理股票 600025 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600025\titles_with_score.csv
# 处理股票 600026 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600026\titles_with_score.csv
# 处理股票 600027 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600027\titles_with_score.csv
# 处理股票 600028 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600028\titles_with_score.csv
# 处理股票 600029 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600029\titles_with_score.csv
# 处理股票 600030 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600030\titles_with_score.csv
# 处理股票 600031 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600031\titles_with_score.csv
# 处理股票 600036 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600036\titles_with_score.csv
# 处理股票 600039 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600039\titles_with_score.csv
# 处理股票 600048 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600048\titles_with_score.csv
# 处理股票 600050 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600050\titles_with_score.csv
# 处理股票 600061 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600061\titles_with_score.csv
# 处理股票 600066 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600066\titles_with_score.csv
# 处理股票 600085 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600085\titles_with_score.csv
# 处理股票 600089 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600089\titles_with_score.csv
# 处理股票 600104 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600104\titles_with_score.csv
# 处理股票 600111 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600111\titles_with_score.csv
# 处理股票 600115 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600115\titles_with_score.csv
# 处理股票 600150 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600150\titles_with_score.csv
# 处理股票 600160 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600160\titles_with_score.csv
# 处理股票 600161 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600161\titles_with_score.csv
# 处理股票 600176 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600176\titles_with_score.csv
# 处理股票 600183 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600183\titles_with_score.csv
# 处理股票 600188 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600188\titles_with_score.csv
# 处理股票 600196 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600196\titles_with_score.csv
# 处理股票 600219 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600219\titles_with_score.csv
# 处理股票 600233 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600233\titles_with_score.csv
# 处理股票 600276 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600276\titles_with_score.csv
# 处理股票 600309 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600309\titles_with_score.csv
# 处理股票 600332 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600332\titles_with_score.csv
# 处理股票 600346 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600346\titles_with_score.csv
# 处理股票 600362 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600362\titles_with_score.csv
# 处理股票 600372 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600372\titles_with_score.csv
# 处理股票 600377 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600377\titles_with_score.csv
# 处理股票 600406 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600406\titles_with_score.csv
# 处理股票 600415 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600415\titles_with_score.csv
# 处理股票 600426 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600426\titles_with_score.csv
# 处理股票 600436 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600436\titles_with_score.csv
# 处理股票 600438 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600438\titles_with_score.csv
# 处理股票 600460 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600460\titles_with_score.csv
# 处理股票 600482 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600482\titles_with_score.csv
# 处理股票 600489 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600489\titles_with_score.csv
# 处理股票 600515 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600515\titles_with_score.csv
# 处理股票 600519 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600519\titles_with_score.csv
# 处理股票 600547 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600547\titles_with_score.csv
# 处理股票 600570 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600570\titles_with_score.csv
# 处理股票 600584 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600584\titles_with_score.csv
# 处理股票 600585 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600585\titles_with_score.csv
# 处理股票 600588 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600588\titles_with_score.csv
# 处理股票 600600 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600600\titles_with_score.csv
# 处理股票 600660 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600660\titles_with_score.csv
# 处理股票 600674 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600674\titles_with_score.csv
# 处理股票 600690 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600690\titles_with_score.csv
# 处理股票 600741 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600741\titles_with_score.csv
# 处理股票 600745 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600745\titles_with_score.csv
# 处理股票 600760 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600760\titles_with_score.csv
# 处理股票 600795 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600795\titles_with_score.csv
# 处理股票 600803 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600803\titles_with_score.csv
# 处理股票 600809 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600809\titles_with_score.csv
# 处理股票 600845 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600845\titles_with_score.csv
# 处理股票 600875 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600875\titles_with_score.csv
# 处理股票 600886 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600886\titles_with_score.csv
# 处理股票 600887 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600887\titles_with_score.csv
# 处理股票 600893 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600893\titles_with_score.csv
# 处理股票 600900 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600900\titles_with_score.csv
# 处理股票 600905 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600905\titles_with_score.csv
# 处理股票 600918 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600918\titles_with_score.csv
# 处理股票 600919 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600919\titles_with_score.csv
# 处理股票 600926 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600926\titles_with_score.csv
# 处理股票 600938 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600938\titles_with_score.csv
# 处理股票 600941 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600941\titles_with_score.csv
# 处理股票 600958 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600958\titles_with_score.csv
# 处理股票 600989 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600989\titles_with_score.csv
# 处理股票 600999 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\600999\titles_with_score.csv
# 处理股票 601006 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601006\titles_with_score.csv
# 处理股票 601009 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601009\titles_with_score.csv
# 处理股票 601012 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601012\titles_with_score.csv
# 处理股票 601021 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601021\titles_with_score.csv
# 处理股票 601058 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601058\titles_with_score.csv
# 处理股票 601059 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601059\titles_with_score.csv
# 处理股票 601066 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601066\titles_with_score.csv
# 处理股票 601088 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601088\titles_with_score.csv
# 处理股票 601100 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601100\titles_with_score.csv
# 处理股票 601111 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601111\titles_with_score.csv
# 处理股票 601117 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601117\titles_with_score.csv
# 处理股票 601127 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601127\titles_with_score.csv
# 处理股票 601136 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601136\titles_with_score.csv
# 处理股票 601138 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601138\titles_with_score.csv
# 处理股票 601166 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601166\titles_with_score.csv
# 处理股票 601169 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601169\titles_with_score.csv
# 处理股票 601186 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601186\titles_with_score.csv
# 处理股票 601211 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601211\titles_with_score.csv
# 处理股票 601225 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601225\titles_with_score.csv
# 处理股票 601229 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601229\titles_with_score.csv
# 处理股票 601236 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601236\titles_with_score.csv
# 处理股票 601238 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601238\titles_with_score.csv
# 处理股票 601288 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601288\titles_with_score.csv
# 处理股票 601318 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601318\titles_with_score.csv
# 处理股票 601319 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601319\titles_with_score.csv
# 处理股票 601328 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601328\titles_with_score.csv
# 处理股票 601336 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601336\titles_with_score.csv
# 处理股票 601360 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601360\titles_with_score.csv
# 处理股票 601377 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601377\titles_with_score.csv
# 处理股票 601390 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601390\titles_with_score.csv
# 处理股票 601398 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601398\titles_with_score.csv
# 处理股票 601600 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601600\titles_with_score.csv
# 处理股票 601601 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601601\titles_with_score.csv
# 处理股票 601607 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601607\titles_with_score.csv
# 处理股票 601618 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601618\titles_with_score.csv
# 处理股票 601628 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601628\titles_with_score.csv
# 处理股票 601633 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601633\titles_with_score.csv
# 处理股票 601658 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601658\titles_with_score.csv
# 处理股票 601668 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601668\titles_with_score.csv
# 处理股票 601669 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601669\titles_with_score.csv
# 处理股票 601688 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601688\titles_with_score.csv
# 处理股票 601689 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601689\titles_with_score.csv
# 处理股票 601698 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601698\titles_with_score.csv
# 处理股票 601699 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601699\titles_with_score.csv
# 处理股票 601728 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601728\titles_with_score.csv
# 处理股票 601766 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601766\titles_with_score.csv
# 处理股票 601788 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601788\titles_with_score.csv
# 处理股票 601799 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601799\titles_with_score.csv
# 处理股票 601800 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601800\titles_with_score.csv
# 处理股票 601808 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601808\titles_with_score.csv
# 处理股票 601816 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601816\titles_with_score.csv
# 处理股票 601818 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601818\titles_with_score.csv
# 处理股票 601838 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601838\titles_with_score.csv
# 处理股票 601857 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601857\titles_with_score.csv
# 处理股票 601865 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601865\titles_with_score.csv
# 处理股票 601868 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601868\titles_with_score.csv
# 处理股票 601872 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601872\titles_with_score.csv
# 处理股票 601877 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601877\titles_with_score.csv
# 处理股票 601878 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601878\titles_with_score.csv
# 处理股票 601881 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601881\titles_with_score.csv
# 处理股票 601888 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601888\titles_with_score.csv
# 处理股票 601898 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601898\titles_with_score.csv
# 处理股票 601899 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601899\titles_with_score.csv
# 处理股票 601901 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601901\titles_with_score.csv
# 处理股票 601916 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601916\titles_with_score.csv
# 处理股票 601919 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601919\titles_with_score.csv
# 处理股票 601939 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601939\titles_with_score.csv
# 处理股票 601985 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601985\titles_with_score.csv
# 处理股票 601988 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601988\titles_with_score.csv
# 处理股票 601989 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601989\titles_with_score.csv
# 处理股票 601995 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601995\titles_with_score.csv
# 处理股票 601998 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\601998\titles_with_score.csv
# 处理股票 603019 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603019\titles_with_score.csv
# 处理股票 603195 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603195\titles_with_score.csv
# 处理股票 603259 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603259\titles_with_score.csv
# 处理股票 603260 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603260\titles_with_score.csv
# 处理股票 603288 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603288\titles_with_score.csv
# 处理股票 603296 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603296\titles_with_score.csv
# 处理股票 603369 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603369\titles_with_score.csv
# 处理股票 603392 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603392\titles_with_score.csv
# 处理股票 603501 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603501\titles_with_score.csv
# 处理股票 603659 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603659\titles_with_score.csv
# 处理股票 603799 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603799\titles_with_score.csv
# 处理股票 603806 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603806\titles_with_score.csv
# 处理股票 603833 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603833\titles_with_score.csv
# 处理股票 603986 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603986\titles_with_score.csv
# 处理股票 603993 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\603993\titles_with_score.csv
# 处理股票 605117 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\605117\titles_with_score.csv
# 处理股票 605499 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\605499\titles_with_score.csv
# 处理股票 688008 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688008\titles_with_score.csv
# 处理股票 688009 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688009\titles_with_score.csv
# 处理股票 688012 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688012\titles_with_score.csv
# 处理股票 688036 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688036\titles_with_score.csv
# 处理股票 688041 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688041\titles_with_score.csv
# 处理股票 688047 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688047\titles_with_score.csv
# 处理股票 688065 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688065\titles_with_score.csv
# 处理股票 688072 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688072\titles_with_score.csv
# 处理股票 688082 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688082\titles_with_score.csv
# 处理股票 688099 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688099\titles_with_score.csv
# 处理股票 688111 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688111\titles_with_score.csv
# 处理股票 688114 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688114\titles_with_score.csv
# 处理股票 688120 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688120\titles_with_score.csv
# 处理股票 688122 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688122\titles_with_score.csv
# 处理股票 688126 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688126\titles_with_score.csv
# 处理股票 688169 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688169\titles_with_score.csv
# 处理股票 688180 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688180\titles_with_score.csv
# 处理股票 688187 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688187\titles_with_score.csv
# 处理股票 688188 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688188\titles_with_score.csv
# 处理股票 688220 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688220\titles_with_score.csv
# 处理股票 688223 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688223\titles_with_score.csv
# 处理股票 688234 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688234\titles_with_score.csv
# 处理股票 688249 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688249\titles_with_score.csv
# 处理股票 688256 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688256\titles_with_score.csv
# 处理股票 688271 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688271\titles_with_score.csv
# 处理股票 688295 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688295\titles_with_score.csv
# 处理股票 688297 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688297\titles_with_score.csv
# 处理股票 688301 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688301\titles_with_score.csv
# 处理股票 688303 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688303\titles_with_score.csv
# 处理股票 688349 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688349\titles_with_score.csv
# 处理股票 688363 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688363\titles_with_score.csv
# 处理股票 688375 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688375\titles_with_score.csv
# 处理股票 688385 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688385\titles_with_score.csv
# 处理股票 688396 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688396\titles_with_score.csv
# 处理股票 688469 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688469\titles_with_score.csv
# 处理股票 688472 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688472\titles_with_score.csv
# 处理股票 688475 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688475\titles_with_score.csv
# 处理股票 688506 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688506\titles_with_score.csv
# 处理股票 688521 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688521\titles_with_score.csv
# 处理股票 688525 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688525\titles_with_score.csv
# 处理股票 688538 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688538\titles_with_score.csv
# 处理股票 688561 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688561\titles_with_score.csv
# 处理股票 688563 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688563\titles_with_score.csv
# 处理股票 688599 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688599\titles_with_score.csv
# 处理股票 688617 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688617\titles_with_score.csv
# 处理股票 688728 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688728\titles_with_score.csv
# 处理股票 688777 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688777\titles_with_score.csv
# 处理股票 688819 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688819\titles_with_score.csv
# 处理股票 688981 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\688981\titles_with_score.csv
# 处理股票 689009 ...
# ✅ 已输出 ../../../mid_result/hs300_data/stocks_words_data\689009\titles_with_score.csv
# 全部处理完成！
